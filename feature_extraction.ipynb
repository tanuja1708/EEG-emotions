# %% [markdown]
# <a href="https://colab.research.google.com/github/tanuja1708/EEG-emotions/blob/main/feature_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# Navigate to the correct directory
csv_file = "/content/processed_eeg_data.csv"
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import scipy.signal as signal
import pywt

# %%
import numpy as np
import pandas as pd
import scipy.signal as signal
import pywt
from scipy import stats # Import the stats module from scipy

def extract_time_features(eeg_signal):
    """Extracts time-domain features from an EEG signal."""
    mean = np.mean(eeg_signal)
    std = np.std(eeg_signal)
    kurtosis = stats.kurtosis(eeg_signal) # Use stats.kurtosis
    skewness = stats.skew(eeg_signal) # Use stats.skew

    print(f"Time Features: Mean={mean}, Std={std}, Kurtosis={kurtosis}, Skewness={skewness}")

    return mean, std, kurtosis, skewness

def extract_frequency_features(eeg_signal, sampling_rate=256):
    """Extracts frequency-domain features using FFT."""
    nperseg = min(256, len(eeg_signal))  # Adjust dynamically
    freqs, psd = signal.welch(eeg_signal, fs=sampling_rate, nperseg=nperseg)

    # Check that power spectral density is not zero for the frequency bands
    delta_range = (freqs >= 0.5) & (freqs < 4)
    theta_range = (freqs >= 4) & (freqs < 8)
    alpha_range = (freqs >= 8) & (freqs < 14)
    beta_range = (freqs >= 14) & (freqs < 30)
    gamma_range = (freqs >= 30) & (freqs < 40)

    delta_power = np.sum(psd[delta_range]) if np.any(delta_range) else 0
    theta_power = np.sum(psd[theta_range]) if np.any(theta_range) else 0
    alpha_power = np.sum(psd[alpha_range]) if np.any(alpha_range) else 0
    beta_power = np.sum(psd[beta_range]) if np.any(beta_range) else 0
    gamma_power = np.sum(psd[gamma_range]) if np.any(gamma_range) else 0

    print(f"Frequency Features: Delta={delta_power}, Theta={theta_power}, Alpha={alpha_power}, Beta={beta_power}, Gamma={gamma_power}")

    return delta_power, theta_power, alpha_power, beta_power, gamma_power


def extract_wavelet_features(eeg_signal, wavelet='db4'):
    """Extracts wavelet transform features with dynamic level adjustment."""
    max_level = pywt.dwt_max_level(len(eeg_signal), pywt.Wavelet(wavelet))
    level = min(3, max_level)  # Ensure level is not too high
    coeffs = pywt.wavedec(eeg_signal, wavelet, level=level)

    wavelet_features = [np.mean(abs(c)) for c in coeffs]

    print(f"Wavelet Features: {wavelet_features}")

    return wavelet_features

def extract_features_from_csv(csv_file):
    """Extracts all features from the EEG dataset."""
    df = pd.read_csv(csv_file)
    feature_list = []

    for index, row in df.iterrows():
        print(f"\nProcessing Row {index+1}/{len(df)}...")
        eeg_signal = np.array(row)

        time_features = extract_time_features(eeg_signal)
        freq_features = extract_frequency_features(eeg_signal)
        wavelet_features = extract_wavelet_features(eeg_signal)

        features = list(time_features) + list(freq_features) + wavelet_features
        feature_list.append(features)

    feature_columns = ["mean", "std", "kurtosis", "skewness", "delta_power", "theta_power", "alpha_power", "beta_power", "gamma_power"] + [f"wavelet_{i}" for i in range(len(wavelet_features))]

    feature_df = pd.DataFrame(feature_list, columns=feature_columns)
    feature_df.to_csv("features.csv", index=False)
    print("\n✅ Feature extraction complete! Saved to features.csv")

# Run feature extraction
extract_features_from_csv("processed_eeg_data.csv")
# Out:
# Streaming output truncated to the last 5000 lines.
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594202/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594203/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594204/595200...
# Time Features: Mean=-0.7539651487744856, Std=7.940466037436444, Kurtosis=2.852533086350146, Skewness=-1.8226687866579052
# Frequency Features: Delta=0, Theta=0, Alpha=0.2493307746417163, Beta=0.030187159969093706, Gamma=0.11146550934044663
# Wavelet Features: [6.228910840054778, 6.057003603277989]
#
# Processing Row 594205/595200...
# Time Features: Mean=-0.7731966935029796, Std=7.619968726003586, Kurtosis=2.180161915194817, Skewness=-1.5865022251074214
# Frequency Features: Delta=0, Theta=0, Alpha=0.2585897265658192, Beta=0.06551636596659141, Gamma=0.06881496742860252
# Wavelet Features: [5.861117106248594, 5.415611279529284]
#
# Processing Row 594206/595200...
# Time Features: Mean=-0.6695238754095212, Std=7.316672185237903, Kurtosis=1.7427764345099428, Skewness=-1.1176000249212057
# Frequency Features: Delta=0, Theta=0, Alpha=0.25937809128376765, Beta=0.11436038597058096, Gamma=0.04577749208285786
# Wavelet Features: [5.192936992656144, 4.751044706848469]
#
# Processing Row 594207/595200...
# Time Features: Mean=-0.5247013360125719, Std=7.252614824183835, Kurtosis=2.0143688148644863, Skewness=-0.9225888175884196
# Frequency Features: Delta=0, Theta=0, Alpha=0.2156139849761068, Beta=0.11066453188030395, Gamma=0.03951797536104862
# Wavelet Features: [4.77624893304112, 4.664182961594406]
#
# Processing Row 594208/595200...
# Time Features: Mean=-0.3564327467316846, Std=7.06713854681197, Kurtosis=2.727256488410312, Skewness=-1.0825596263422193
# Frequency Features: Delta=0, Theta=0, Alpha=0.14040098693825961, Beta=0.05632677627164529, Gamma=0.0271437704722936
# Wavelet Features: [4.557960151682517, 4.663956704732426]
#
# Processing Row 594209/595200...
# Time Features: Mean=-0.5363946200360448, Std=6.911515572425094, Kurtosis=3.0555355151974437, Skewness=-1.2467224588734849
# Frequency Features: Delta=0, Theta=0, Alpha=0.10434665511367043, Beta=0.021874295300429922, Gamma=0.014693936157822843
# Wavelet Features: [4.443010677711466, 4.605681127095433]
#
# Processing Row 594210/595200...
# Time Features: Mean=-1.0555355927510317, Std=6.572123134545897, Kurtosis=3.4965087118723774, Skewness=-1.47460221015602
# Frequency Features: Delta=0, Theta=0, Alpha=0.08469928120854908, Beta=0.004354644474120408, Gamma=0.014203844021526912
# Wavelet Features: [4.661682870703567, 4.295972964859089]
#
# Processing Row 594211/595200...
# Time Features: Mean=-1.2889298646685516, Std=6.206845530617799, Kurtosis=4.170542342948408, Skewness=-1.7208217305782874
# Frequency Features: Delta=0, Theta=0, Alpha=0.08673195420535064, Beta=0.0133966278793817, Gamma=0.029344875991165746
# Wavelet Features: [4.708094884972246, 4.1501554126375355]
#
# Processing Row 594212/595200...
# Time Features: Mean=-1.3538176116347838, Std=5.907535937723281, Kurtosis=4.831882054492774, Skewness=-1.920800445744973
# Frequency Features: Delta=0, Theta=0, Alpha=0.13393599274348997, Beta=0.030925964446921778, Gamma=0.0469053677824883
# Wavelet Features: [4.449764387601689, 4.2862286966966066]
#
# Processing Row 594213/595200...
# Time Features: Mean=-1.3810850037567006, Std=5.741676400297436, Kurtosis=4.936721143098962, Skewness=-1.9168417977605074
# Frequency Features: Delta=0, Theta=0, Alpha=0.1822282222598939, Beta=0.052769014420163664, Gamma=0.064630224947347
# Wavelet Features: [4.1580459129677685, 4.4261013042724535]
#
# Processing Row 594214/595200...
# Time Features: Mean=-1.2857165771964136, Std=5.989994792402625, Kurtosis=3.259368717671234, Skewness=-1.3396060154699905
# Frequency Features: Delta=0, Theta=0, Alpha=0.24367922418954582, Beta=0.07475482137760324, Gamma=0.07551325764031419
# Wavelet Features: [4.769703110887485, 4.588502950840954]
#
# Processing Row 594215/595200...
# Time Features: Mean=-1.3722420830478772, Std=6.221690633321226, Kurtosis=1.919698328150976, Skewness=-1.0229016997372702
# Frequency Features: Delta=0, Theta=0, Alpha=0.3248329783928981, Beta=0.08805999137392646, Gamma=0.07632444131130724
# Wavelet Features: [5.465844255655125, 4.753263198354293]
#
# Processing Row 594216/595200...
# Time Features: Mean=-1.4149364047286586, Std=6.02680209371308, Kurtosis=1.7491298137312672, Skewness=-1.1656452878404029
# Frequency Features: Delta=0, Theta=0, Alpha=0.3721488872657777, Beta=0.0863846830238293, Gamma=0.05787668192633915
# Wavelet Features: [5.450800290457506, 4.568592452103429]
#
# Processing Row 594217/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594218/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594219/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594220/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594221/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594222/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594223/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594224/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594225/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594226/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594227/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594228/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594229/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594230/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594231/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594232/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594233/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594234/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594235/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594236/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594237/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594238/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594239/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594240/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594241/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594242/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594243/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594244/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594245/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594246/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594247/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594248/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594249/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594250/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594251/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594252/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594253/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594254/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594255/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594256/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594257/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594258/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594259/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594260/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594261/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594262/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594263/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594264/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594265/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594266/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594267/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594268/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594269/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594270/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594271/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594272/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594273/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594274/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594275/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594276/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594277/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594278/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594279/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594280/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594281/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594282/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594283/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594284/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594285/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594286/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594287/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594288/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594289/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594290/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594291/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594292/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594293/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594294/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594295/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594296/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594297/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594298/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594299/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594300/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594301/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594302/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594303/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594304/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594305/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594306/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594307/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594308/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594309/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594310/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594311/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594312/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594313/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594314/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594315/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594316/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594317/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594318/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594319/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594320/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594321/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594322/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594323/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594324/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594325/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594326/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594327/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594328/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594329/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594330/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594331/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594332/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594333/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594334/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594335/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594336/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594337/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594338/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594339/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594340/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594341/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594342/595200...
# Time Features: Mean=3.4317520871054357, Std=7.625577065397036, Kurtosis=1.316453330581905, Skewness=0.5397375253786265
# Frequency Features: Delta=0, Theta=0, Alpha=0.040088151780010836, Beta=0.6192699614678409, Gamma=0.6440243748236456
# Wavelet Features: [5.403415032160412, 6.387850499456158]
#
# Processing Row 594343/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594344/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594345/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594346/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594347/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594348/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594349/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594350/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594351/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594352/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594353/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594354/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594355/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594356/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594357/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594358/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594359/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594360/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594361/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594362/595200...
# Time Features: Mean=4.406630278750449, Std=6.849998613580552, Kurtosis=-0.10802950253518562, Skewness=0.3101182754368249
# Frequency Features: Delta=0, Theta=0, Alpha=0.10957343011945808, Beta=0.33993252671447, Gamma=0.32123323446919844
# Wavelet Features: [7.176854662413937, 6.397362870834757]
#
# Processing Row 594363/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594364/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594365/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594366/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594367/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594368/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594369/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594370/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594371/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594372/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594373/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594374/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594375/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594376/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594377/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594378/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594379/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594380/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594381/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594382/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594383/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594384/595200...
# Time Features: Mean=-0.1736776380559535, Std=6.551560067600493, Kurtosis=-0.6602243436042308, Skewness=-0.3682538673330612
# Frequency Features: Delta=0, Theta=0, Alpha=0.28049791965910575, Beta=0.2829646458372607, Gamma=0.16393789319140348
# Wavelet Features: [4.442919923634602, 5.347051706765308]
#
# Processing Row 594385/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594386/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594387/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594388/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594389/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594390/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594391/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594392/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594393/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594394/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594395/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594396/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594397/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594398/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594399/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594400/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594401/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594402/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594403/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594404/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594405/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594406/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594407/595200...
# Time Features: Mean=1.2344602954776736, Std=6.183587025200869, Kurtosis=-1.1100988215844083, Skewness=0.39198240720835437
# Frequency Features: Delta=0, Theta=0, Alpha=0.1070306217936428, Beta=0.15250352856181257, Gamma=0.49848568200280946
# Wavelet Features: [5.149519383442209, 3.979130424619306]
#
# Processing Row 594408/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594409/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594410/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594411/595200...
# Time Features: Mean=0.07164557730784644, Std=6.0027298584741615, Kurtosis=-0.4555323808150473, Skewness=-0.02428838633531323
# Frequency Features: Delta=0, Theta=0, Alpha=0.027093389565010274, Beta=0.3547606123632312, Gamma=0.25964659175149274
# Wavelet Features: [5.862491702183017, 3.8970861285338834]
#
# Processing Row 594412/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594413/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594414/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594415/595200...
# Time Features: Mean=-2.3468829778916835, Std=6.763604907474373, Kurtosis=-0.23174471719361778, Skewness=-0.6946255696989958
# Frequency Features: Delta=0, Theta=0, Alpha=0.33577067155466367, Beta=0.32240831465220243, Gamma=0.4437865576453194
# Wavelet Features: [6.45563699764837, 4.664276103691009]
#
# Processing Row 594416/595200...
# Time Features: Mean=-1.8664279428168744, Std=6.4614276419496965, Kurtosis=-0.7309539638854337, Skewness=-0.6232006819594598
# Frequency Features: Delta=0, Theta=0, Alpha=0.2739488119608521, Beta=0.2706452430948976, Gamma=0.4136589803420847
# Wavelet Features: [5.989931017227234, 4.915670193470187]
#
# Processing Row 594417/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594418/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594419/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594420/595200...
# Time Features: Mean=-2.043095537233688, Std=7.1868774279836805, Kurtosis=-0.005806358107086407, Skewness=-0.4126076197275863
# Frequency Features: Delta=0, Theta=0, Alpha=0.40812079930934897, Beta=0.18990138554664474, Gamma=0.4320716447550101
# Wavelet Features: [6.428359571687944, 4.958293692699296]
#
# Processing Row 594421/595200...
# Time Features: Mean=-1.7883072483121245, Std=7.395867035889726, Kurtosis=-0.1505924112887267, Skewness=0.0738494661929126
# Frequency Features: Delta=0, Theta=0, Alpha=0.24293291735591177, Beta=0.31568950235837756, Gamma=0.5359991335655564
# Wavelet Features: [6.930877005394964, 5.023976098679606]
#
# Processing Row 594422/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594423/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594424/595200...
# Time Features: Mean=-1.022538532889048, Std=7.213874360610913, Kurtosis=1.1890631646061225, Skewness=-0.2458784646085997
# Frequency Features: Delta=0, Theta=0, Alpha=0.005665101756295464, Beta=0.6301885246037552, Gamma=0.8689178361039724
# Wavelet Features: [7.339519615388069, 4.466512078019531]
#
# Processing Row 594425/595200...
# Time Features: Mean=-1.3199861767148569, Std=7.595841017087061, Kurtosis=1.3611796346205018, Skewness=-0.43559993191079355
# Frequency Features: Delta=0, Theta=0, Alpha=0.024595299962464432, Beta=0.634715998438723, Gamma=1.045805994413547
# Wavelet Features: [7.738933909752221, 3.4565021086783587]
#
# Processing Row 594426/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594427/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594428/595200...
# Time Features: Mean=-1.3891276392892742, Std=8.059173253961342, Kurtosis=1.064324040727131, Skewness=-0.46378422077007847
# Frequency Features: Delta=0, Theta=0, Alpha=0.4675876289396762, Beta=0.7746896463382101, Gamma=0.8766324521372235
# Wavelet Features: [8.153009924237947, 3.694055892339967]
#
# Processing Row 594429/595200...
# Time Features: Mean=-1.313206545822758, Std=7.826312217798447, Kurtosis=1.4838383431644502, Skewness=-0.23694751415948212
# Frequency Features: Delta=0, Theta=0, Alpha=0.6176638508113319, Beta=0.987139935774933, Gamma=0.7592250248287141
# Wavelet Features: [7.689557228202924, 4.233962736110063]
#
# Processing Row 594430/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594431/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 594432/595200...
# ...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595121/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595122/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595123/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595124/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595125/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595126/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595127/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595128/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595129/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595130/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595131/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595132/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595133/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595134/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595135/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595136/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595137/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595138/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595139/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595140/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595141/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595142/595200...
# Time Features: Mean=3.869376784460792, Std=11.947924175720283, Kurtosis=2.7273630172974004, Skewness=-0.06040516573920266
# Frequency Features: Delta=0, Theta=0, Alpha=0.18891837360098374, Beta=0.047963306324502665, Gamma=1.0236775082004121
# Wavelet Features: [9.007916154241391, 9.989189236180573]
#
# Processing Row 595143/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595144/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595145/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595146/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595147/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595148/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595149/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595150/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595151/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595152/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595153/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595154/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595155/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595156/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595157/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595158/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595159/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595160/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595161/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595162/595200...
# Time Features: Mean=4.395169643482709, Std=10.649091865863822, Kurtosis=1.805238975319634, Skewness=0.11731544560712533
# Frequency Features: Delta=0, Theta=0, Alpha=0.03605135067322356, Beta=0.18907938520797243, Gamma=0.7320313353810013
# Wavelet Features: [9.622547543057284, 9.716028243244283]
#
# Processing Row 595163/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595164/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595165/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595166/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595167/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595168/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595169/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595170/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595171/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595172/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595173/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595174/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595175/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595176/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595177/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595178/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595179/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595180/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595181/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595182/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595183/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595184/595200...
# Time Features: Mean=1.0878420547095173, Std=5.29158937066965, Kurtosis=-1.0416718002903997, Skewness=-0.32370571302802836
# Frequency Features: Delta=0, Theta=0, Alpha=0.034294233505461805, Beta=0.10939745718775447, Gamma=0.05043313113156913
# Wavelet Features: [5.182592231421233, 4.197454643410896]
#
# Processing Row 595185/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595186/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595187/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595188/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595189/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595190/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595191/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595192/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595193/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595194/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595195/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595196/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595197/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595198/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595199/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# Processing Row 595200/595200...
# Time Features: Mean=nan, Std=nan, Kurtosis=nan, Skewness=nan
# Frequency Features: Delta=0, Theta=0, Alpha=nan, Beta=nan, Gamma=nan
# Wavelet Features: [nan, nan]
#
# ✅ Feature extraction complete! Saved to features.csv

# %%
import pandas as pd
features_df = pd.read_csv("features.csv")
print(features_df.head())  # Check if features are loaded correctly
# Out:
#        mean        std  kurtosis  skewness  delta_power  theta_power  \
# 0  4.038891  22.657806  2.783158  1.680400            0            0
# 1  4.219708  22.952227  2.739531  1.760415            0            0
# 2  3.934278  22.820650  2.903568  1.808757            0            0
# 3  3.265196  22.386151  3.142232  1.783666            0            0
# 4  2.748455  21.861870  2.596507  1.566632            0            0
#
#    alpha_power  beta_power  gamma_power  wavelet_0  wavelet_1
# 0     0.858203    7.227299    11.251215  16.359229  15.880550
# 1     1.283106    8.021003    10.323559  16.923806  14.828284
# 2     1.409273    7.983557     9.292759  16.549160  14.808020
# 3     1.343231    7.180577     8.344166  14.744352  15.851768
# 4     1.347622    6.269381     7.542285  14.483288  16.344409

# %%
import pandas as pd

# Load extracted features
features_df = pd.read_csv("features.csv")

def assign_emotion_label(row):
    delta, theta, alpha, beta, gamma = row['delta_power'], row['theta_power'], row['alpha_power'], row['beta_power'], row.get('gamma_power', 0)

    if beta > alpha and gamma > theta:
        return 'Happy'
    elif delta > alpha and theta > beta:
        return 'Sad'
    elif alpha > theta and alpha > beta:
        return 'Calm'
    elif gamma > beta and gamma > alpha:
        return 'Angry'
    elif theta > alpha and gamma > beta:
        return 'Anxious'
    elif beta > delta and alpha > theta:
        return 'Excited'
    else:
        return 'Neutral'

# Apply labeling function
features_df['label'] = features_df.apply(assign_emotion_label, axis=1)

# Save labeled dataset
features_df.to_csv("labeled_eeg_data.csv", index=False)
print("✅ Labeled dataset saved as labeled_eeg_data.csv")
# Out:
# ✅ Labeled dataset saved as labeled_eeg_data.csv

# %%
print(features_df['label'].value_counts())
# Out:
# label
# Happy      247571
# Neutral    178684
# Calm       168945
# Name: count, dtype: int64
